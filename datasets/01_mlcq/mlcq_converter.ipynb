# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Users/hash/Desktop/smellBERT/venv/lib/python3.13/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /Users/hash/Desktop/smellBERT/venv/lib/python3.13/site-packages (from openpyxl) (2.0.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import openpyxl
import sys
sys.path.append("..")
from utils.github_utils import GithubUtils
from utils.java_code_cleaner import JavaCodeCleaner
from utils.code_smells import CodeSmells
from utils.dataset_utils import *

# %%
dataset_file_path = "./input/mlcq_dataset.csv"

#! Open & Sort MLCQ_Dataset
originalDf = pd.read_csv(
    dataset_file_path, on_bad_lines="skip").sort_values(by=["sample_id", "reviewer_id", "smell"])

# display(originalDf)

# print("Dataset Columns:", originalDf.columns)

# #! Digitalize Severity Value
severity_digital_values = {
    "none": 0,
    "minor": 1,
    "major": 2,
    "critical": 3
}

originalDf["severity"] = originalDf["severity"].replace(
    severity_digital_values
).astype(int)

# display(originalDf)

# #! Filter Class Instances
classOnlyDf = originalDf[(originalDf["type"] == "class")]

# display(classOnlyDf)

#! Group By CodeName & Smell
groupedBySmellDf = classOnlyDf.groupby(["code_name", "smell"], as_index=False).agg(
    repository=("repository", "first"),
    commit_hash=("commit_hash", "first"),
    file_path=("path", "first"),
    github_url=("link", "first"),
    severity_sum=("severity", "sum"),
    reviewers_count=("reviewer_id", "count")
)

groupedBySmellDf["smelliness_degree"] = groupedBySmellDf.apply(
    lambda row: row["severity_sum"] / row["reviewers_count"], axis=1
)

# Remove Extra #L**-L** from GithubURL
groupedBySmellDf["github_url"] = groupedBySmellDf["github_url"].apply(
    lambda url: url[0:url.rfind("/")]
)



preprocessedDf = groupedBySmellDf

display(preprocessedDf)
# Out:
# /var/folders/2w/crm4crcx47q8y6l_5h_49ldr0000gn/T/ipykernel_26373/376510704.py:19: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   originalDf["severity"] = originalDf["severity"].replace(
#                                     code_name       smell  \
# 0                                  Foo.Mumble        blob
# 1                                  Foo.Mumble  data class
# 2                                   GetObject        blob
# 3                                   GetObject  data class
# 4                               ICEDocCleaner        blob
# ...                                       ...         ...
# 4393             tv.sage.SageRuntimeException  data class
# 4394  userguide.clients.EchoNonBlockingClient        blob
# 4395  userguide.clients.EchoNonBlockingClient  data class
# 4396               websocket.drawboard.Client        blob
# 4397               websocket.drawboard.Client  data class
#
#                                              repository  \
# 0                git@github.com:eclipse/org.aspectj.git
# 1                git@github.com:eclipse/org.aspectj.git
# 2     git@github.com:awsdocs/amazon-s3-developer-gui...
# 3     git@github.com:awsdocs/amazon-s3-developer-gui...
# 4                        git@github.com:eclipse/ice.git
# ...                                                 ...
# 4393                   git@github.com:google/sagetv.git
# 4394               git@github.com:apache/axis2-java.git
# 4395               git@github.com:apache/axis2-java.git
# 4396                   git@github.com:apache/tomcat.git
# 4397                   git@github.com:apache/tomcat.git
#
#                                    commit_hash  \
# 0     370f291c359cd159c5f3f0abd6e9e53e81234a07
# 1     370f291c359cd159c5f3f0abd6e9e53e81234a07
# 2     038ef11c43698df29de7bb128522dc19a1b645ae
# 3     038ef11c43698df29de7bb128522dc19a1b645ae
# 4     3f6e0265f5b476ff90a660397ce83992944142c4
# ...                                        ...
# 4393  a35e3a450b4c0134cb097b9e7de76dca08eb6654
# 4394  372582df483eb7991f85b6d0e765aec62339cdb7
# 4395  372582df483eb7991f85b6d0e765aec62339cdb7
# 4396  a9c1a0661198d9ba37c1facd8385fe05d538c4ad
# 4397  a9c1a0661198d9ba37c1facd8385fe05d538c4ad
#
#                                               file_path  \
# 0                /asm/testdata/simple-coverage/Foo.java
# 1                /asm/testdata/simple-coverage/Foo.java
# 2     /code_examples/java_examples/S3Examples/GetObj...
# 3     /code_examples/java_examples/S3Examples/GetObj...
# 4           /utils/ICEDocCleaner/src/ICEDocCleaner.java
# ...                                                 ...
# 4393            /java/tv/sage/SageRuntimeException.java
# 4394  /modules/samples/userguide/src/userguide/clien...
# 4395  /modules/samples/userguide/src/userguide/clien...
# 4396  /webapps/examples/WEB-INF/classes/websocket/dr...
# 4397  /webapps/examples/WEB-INF/classes/websocket/dr...
#
#                                              github_url  severity_sum  \
# 0     https://github.com/eclipse/org.aspectj/blob/37...             0
# 1     https://github.com/eclipse/org.aspectj/blob/37...             0
# 2     https://github.com/awsdocs/amazon-s3-developer...             0
# 3     https://github.com/awsdocs/amazon-s3-developer...             0
# 4     https://github.com/eclipse/ice/blob/3f6e0265f5...             2
# ...                                                 ...           ...
# 4393  https://github.com/google/sagetv/blob/a35e3a45...             4
# 4394  https://github.com/apache/axis2-java/blob/3725...             0
# 4395  https://github.com/apache/axis2-java/blob/3725...             0
# 4396  https://github.com/apache/tomcat/blob/a9c1a066...             0
# 4397  https://github.com/apache/tomcat/blob/a9c1a066...             0
#
#       reviewers_count  smelliness_degree
# 0                   1           0.000000
# 1                   1           0.000000
# 2                   1           0.000000
# 3                   1           0.000000
# 4                   3           0.666667
# ...               ...                ...
# 4393                3           1.333333
# 4394                1           0.000000
# 4395                1           0.000000
# 4396                1           0.000000
# 4397                1           0.000000
#
# [4398 rows x 9 columns]

# %%
#! Cols names:
id_col = "id"
github_url_col = "github_url"
github_raw_url_col = "github_raw_url"
is_blob_col = CodeSmells.isBlob
is_data_class_col = CodeSmells.isDataClass

intermediate_dataset = {
    id_col: [],  # A sequential Id
    github_url_col: [],  # Github normal URL of the instance
    github_raw_url_col: [],  # Github Raw URL of the instance
    is_blob_col: [],  # 1 If Instance has a Blob Smell, Otherwise 0
    is_data_class_col: []  # 1 If Instance has a DataClass Smell, Otherwise 0
}


for i, row in preprocessedDf.iterrows():
    if (i % 2 == 0):
        intermediate_dataset[id_col].append(i // 2 + 1)
        intermediate_dataset[github_url_col].append(row["github_url"])
        intermediate_dataset[github_raw_url_col].append(
            GithubUtils.convert_blob_to_raw_url(row["github_url"]))
        intermediate_dataset[is_blob_col].append(
            1 if row["smelliness_degree"] > 0.5 else 0)
    else:
        intermediate_dataset[is_data_class_col].append(
            1 if row["smelliness_degree"] > 0.5 else 0)


intermediate_dataset_df = pd.DataFrame(intermediate_dataset)


#! Save Intermediate Dataset to a CSV file
intermediate_dataset_csv_path = "./output/mlcq_intermediate_dataset.csv"
intermediate_dataset_df.to_csv(intermediate_dataset_csv_path, index=False)


#! Save Intermediate Dataset to a XLSX file
intermediate_dataset_xlsx_path = "./output/mlcq_intermediate_dataset.xlsx"
intermediate_dataset_df.to_excel(intermediate_dataset_xlsx_path, index=False, engine='openpyxl')

# %%
intermediate_dataset_path = "./output/mlcq_intermediate_dataset.csv"

#! Open Intermediate Dataset
intermediateDf = pd.read_csv(
    intermediate_dataset_path, on_bad_lines="skip")

# intermediateDf = intermediateDf[(intermediateDf[CodeSmells.isBlob] == 1) | (
#     intermediateDf[CodeSmells.isDataClass] == 1)]

display(intermediateDf)

mld_items = []
for i, row in intermediateDf.iterrows():
    # if i <= 30:
        source_code = GithubUtils.clone_code(row["github_raw_url"])
        if source_code:
            processed_source_code = JavaCodeCleaner.clean(source_code)

            code_smells = []
            if row["isBlob"] == 1:
                code_smells.append(CodeSmells.Blob)
            if row["isDataClass"] == 1:
                code_smells.append(CodeSmells.DataClass)
            
            item = JsonDatasetUtils.create_item(
                code_smells, processed_source_code
            )
            mld_items.append(item)
# Out:
#         id                                         github_url  \
# 0        1  https://github.com/eclipse/org.aspectj/blob/37...
# 1        2  https://github.com/awsdocs/amazon-s3-developer...
# 2        3  https://github.com/eclipse/ice/blob/3f6e0265f5...
# 3        4  https://github.com/oracle/oci-java-sdk/blob/76...
# 4        5  https://github.com/alibaba/java-dns-cache-mani...
# ...    ...                                                ...
# 2194  2195  https://github.com/google/j2objc/blob/471504a7...
# 2195  2196  https://github.com/eclipse/xtext-xtend/blob/20...
# 2196  2197  https://github.com/google/sagetv/blob/a35e3a45...
# 2197  2198  https://github.com/apache/axis2-java/blob/3725...
# 2198  2199  https://github.com/apache/tomcat/blob/a9c1a066...
#
#                                          github_raw_url  isBlob  isDataClass
# 0     https://raw.githubusercontent.com/eclipse/org....       0            0
# 1     https://raw.githubusercontent.com/awsdocs/amaz...       0            0
# 2     https://raw.githubusercontent.com/eclipse/ice/...       1            0
# 3     https://raw.githubusercontent.com/oracle/oci-j...       0            0
# 4     https://raw.githubusercontent.com/alibaba/java...       1            0
# ...                                                 ...     ...          ...
# 2194  https://raw.githubusercontent.com/google/j2obj...       0            0
# 2195  https://raw.githubusercontent.com/eclipse/xtex...       0            0
# 2196  https://raw.githubusercontent.com/google/saget...       0            1
# 2197  https://raw.githubusercontent.com/apache/axis2...       0            0
# 2198  https://raw.githubusercontent.com/apache/tomca...       0            0
#
# [2199 rows x 5 columns]
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 404: FAILED Code Clone
# 404: FAILED Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# EXCEPTION: FAILED Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone
# 200: SUCCESS Code Clone

# %%
import json

mld_json_file_path = "./output/mlcq_mld_sc.json"

with open(mld_json_file_path, 'w') as mld_json:
    json.dump(mld_items, mld_json)
    mld_json.write('\n')
